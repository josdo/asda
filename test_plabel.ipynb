# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !python generate_plabel_dstl.py \
    --model DeeplabMulti \
    --restore-from ./snapshots/exp9/dstl_25000.pth \
    --batchsize 16 \
    --data-list ./dataset/dstl_list/train.txt \
    --save ./data/dstl/pseudo/train
# Out:
# generate_plabel_dstl.py:109: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)
# ModelType:DeepLab
# NormType:gn
# torch.Size([16, 3, 1000, 1000])
# >>>>Extracting feature...0000/0900./data/dstl/pseudo/train/6120_2_0_201_174.jpg
# ./data/dstl/pseudo/train/6060_2_3_201_2174.jpg
# ./data/dstl/pseudo/train/6110_3_1_198_2174.jpg
# ./data/dstl/pseudo/train/6140_3_1_198_2174.jpg
# ./data/dstl/pseudo/train/6120_2_0_1201_174.jpg
# ./data/dstl/pseudo/train/6110_3_1_2198_174.jpg
# ./data/dstl/pseudo/train/6110_1_2_1198_174.jpg
# ./data/dstl/pseudo/train/6100_2_2_1195_1174.jpg
# ./data/dstl/pseudo/train/6120_2_0_2201_2174.jpg
# ./data/dstl/pseudo/train/6110_1_2_2198_174.jpg
# ./data/dstl/pseudo/train/6100_2_2_195_174.jpg
# ./data/dstl/pseudo/train/6140_1_2_1198_174.jpg
# ./data/dstl/pseudo/train/6140_3_1_198_174.jpg
# ...
