# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

# %%
"""Experiment 2: add image augmentation, training to last conv block"""
# Settings from reduce_bias experiments:
# lr 2.5e-4 (1e-4 backup), focal gamma 2

# New settings:
# 1000 its, 50 val interval

# Notes:
# rotate + flip + color jitter --

# %%
# rotate, flip, color jitter
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0.2 \
    --use-se \
    --norm-style gn \
    --learning_rate 2.5e-4 \
    --focal_gamma 2 \
    --total_itrs 1000 \
    --loss_type focal_loss \
    --exp_name 2_reduce_variance \
    --goal_name aug_img \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 50 \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/1000, Loss=0.782144
# Model saved as checkpoints/aug_img_2_reduce_variance/latest_lr0.00025_gam2_drop0.20.pth
# validation...
# 92it [02:34,  1.66s/it]

# %%
"""Experiment 1: vary dropout rate, training to last conv block"""
# Settings from reduce_bias experiments:
# lr 2.5e-4 (1e-4 backup), focal gamma 2

# New settings:
# 90 its, 30 val interval

# Notes:
# 0 similar to 0.1
# 0.2 has higher loss, slightly lower mIOU at 90 its, but steeper growth in mIOU
# Go with more regularization for now
# RESULT: use 0.2 dropout
# Out:
# 'Experiment 1: vary dropout rate, training to last conv block'

# %%
# droprate 0.2
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0.2 \
    --use-se \
    --norm-style gn \
    --learning_rate 2.5e-4 \
    --focal_gamma 2 \
    --total_itrs 90 \
    --loss_type focal_loss \
    --exp_name 2_reduce_variance \
    --goal_name vary_dropout \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 30 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/90, Loss=0.584745
# Epoch 1, Itrs 20/90, Loss=0.465015
# Epoch 1, Itrs 30/90, Loss=0.699892
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.20.pth
# validation...
# 95it [09:27,  5.98s/it]
#
# Overall Acc: 0.657452
# Mean Acc: 0.491933
# FreqW Acc: 0.478951
# Mean IoU: 0.370810
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.20.pth
# Epoch 1, Itrs 40/90, Loss=0.464006
# Epoch 1, Itrs 50/90, Loss=0.504871
# Epoch 1, Itrs 60/90, Loss=0.365429
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.20.pth
# validation...
# 95it [09:28,  5.98s/it]
#
# Overall Acc: 0.660640
# Mean Acc: 0.548034
# FreqW Acc: 0.478982
# Mean IoU: 0.400422
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.20.pth
# ...

# %%
# droprate 0.1
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0.1 \
    --use-se \
    --norm-style gn \
    --learning_rate 2.5e-4 \
    --focal_gamma 2 \
    --total_itrs 90 \
    --loss_type focal_loss \
    --exp_name 2_reduce_variance \
    --goal_name vary_dropout \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 30 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/90, Loss=0.565004
# Epoch 1, Itrs 20/90, Loss=0.444057
# Epoch 1, Itrs 30/90, Loss=0.543282
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.10.pth
# validation...
# 95it [09:28,  5.98s/it]
#
# Overall Acc: 0.647458
# Mean Acc: 0.514280
# FreqW Acc: 0.465766
# Mean IoU: 0.381775
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.10.pth
# Epoch 1, Itrs 40/90, Loss=0.432792
# Epoch 1, Itrs 50/90, Loss=0.386634
# Epoch 1, Itrs 60/90, Loss=0.334634
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.10.pth
# validation...
# 95it [09:29,  5.99s/it]
#
# Overall Acc: 0.692527
# Mean Acc: 0.556229
# FreqW Acc: 0.520315
# Mean IoU: 0.423109
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.10.pth
# ...

# %%
# droprate 0
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 2.5e-4 \
    --focal_gamma 2 \
    --total_itrs 90 \
    --loss_type focal_loss \
    --exp_name 2_reduce_variance \
    --goal_name vary_dropout \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 30 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/90, Loss=0.534965
# Epoch 1, Itrs 20/90, Loss=0.422659
# Epoch 1, Itrs 30/90, Loss=0.517433
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.00.pth
# validation...
# 95it [09:27,  5.98s/it]
#
# Overall Acc: 0.632805
# Mean Acc: 0.514423
# FreqW Acc: 0.448603
# Mean IoU: 0.377026
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.00.pth
# Epoch 1, Itrs 40/90, Loss=0.400482
# Epoch 1, Itrs 50/90, Loss=0.322966
# Epoch 1, Itrs 60/90, Loss=0.298259
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.00.pth
# validation...
# 95it [09:28,  5.98s/it]
#
# Overall Acc: 0.698962
# Mean Acc: 0.561199
# FreqW Acc: 0.528847
# Mean IoU: 0.430853
#
# Model saved as checkpoints/vary_dropout_2_reduce_variance/latest_lr0.00025_gam2_drop0.00.pth
# ...
