# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np

# %%
"""Experiment 2: train both ASPP classifiers (aux and main) + last conv block (layer 4) 
                 with coarse search over lr, focal gamma"""
# Notes:
# batchsize needed to drop from 6 to 2 -- much slower training, in order to load all these params

# OOM after 5 epochs with batch_size + val_batch_size 2
# -- gradient checkpointing ASPP main (REQUIRES layer 4 unfrozen) 
# -- TODO: toggle on for args.unfreeze_to == "last_conv_aspp_both"

# OOM after 30 epochs with above checkpointing (456 MB free, 536 MiB alloc'd)
# -- checkpoint within each layer?
# -- # parameters: 65,987,744 layer 4,5,6 | 51,023,008 layer 5,6 | 35,210,832 layer 6
# -- checkpoint both ASPP, they take up the most parameters

# NB: learning_rate arg for aspp is 10x'd, and for backbone is 1x'd

# TODO: fixed model weights path to not round learning rate floats

# Coarse search:
# (1e-4, 2), (5e-4, 2) --> loss close to 0.2 for it50-it60
# (1e-3, 2) --> loss close to 0.3 (only ran for shorter 30 its)

# Focus coarse search on lr 1e-5 to 5e-4, gamma 1.8 to 2.2
lrs = np.power(10, np.random.uniform(-5, -3.3, size=3)) # sample log lrs, i.e. -5 to −3.3
gammas = np.random.uniform(1.8, 2.2, size=3)
list(zip(np.round(lrs, 6), np.round(gammas, 2)))

# (8.7e-05, 2.11)
# (0.0001, 1.91)
# (9.5e-05, 2.14)
# Out:
# [(8.7e-05, 2.11), (0.0001, 1.91), (9.5e-05, 2.14)]

# %%
# (8.7e-05, 2.11)
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 8.7e-05 \
    --focal_gamma 2.11 \
    --total_itrs 80 \
    --loss_type focal_loss \
    --exp_name 1_overfit \
    --goal_name last_conv_unfreeze \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 100 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190

# %%
# (1e-4, 2)
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 1e-4 \
    --focal_gamma 2 \
    --total_itrs 60 \
    --loss_type focal_loss \
    --exp_name 1_overfit \
    --goal_name last_conv_unfreeze \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/60, Loss=0.450337
# Epoch 1, Itrs 20/60, Loss=0.402730
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.93s/it]
#
# Overall Acc: 0.623213
# Mean Acc: 0.488917
# FreqW Acc: 0.442902
# Mean IoU: 0.362993
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 30/60, Loss=0.486023
# Epoch 1, Itrs 40/60, Loss=0.399323
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:24,  5.94s/it]
#
# Overall Acc: 0.673340
# Mean Acc: 0.538207
# FreqW Acc: 0.497709
# Mean IoU: 0.403811
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 50/60, Loss=0.342200
# Epoch 1, Itrs 60/60, Loss=0.351918
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.93s/it]
#
# ...

# %%
# (5e-4, 2)
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 5e-4 \
    --focal_gamma 2 \
    --total_itrs 60 \
    --loss_type focal_loss \
    --exp_name 1_overfit \
    --goal_name last_conv_unfreeze \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/60, Loss=0.609859
# Epoch 1, Itrs 20/60, Loss=0.594708
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.93s/it]
#
# Overall Acc: 0.520121
# Mean Acc: 0.406484
# FreqW Acc: 0.329776
# Mean IoU: 0.284022
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 30/60, Loss=0.605732
# Epoch 1, Itrs 40/60, Loss=0.388954
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.93s/it]
#
# Overall Acc: 0.692497
# Mean Acc: 0.539316
# FreqW Acc: 0.527220
# Mean IoU: 0.424759
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 50/60, Loss=0.335648
# Epoch 1, Itrs 60/60, Loss=0.291701
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.93s/it]
#
# ...

# %%
# (1e-3, 2)
# !python main.py \
    --unfreeze_to 'last_conv_aspp_both' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 1e-3 \
    --focal_gamma 2 \
    --total_itrs 100 \
    --loss_type focal_loss \
    --exp_name 1_overfit \
    --goal_name last_conv_unfreeze \
    --batch_size 2 \
    --val_batch_size 2 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Epoch 1, Itrs 10/100, Loss=0.891280
# Epoch 1, Itrs 20/100, Loss=0.786934
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:23,  5.94s/it]
#
# Overall Acc: 0.550845
# Mean Acc: 0.402402
# FreqW Acc: 0.360851
# Mean IoU: 0.284633
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 30/100, Loss=0.566743
# Epoch 1, Itrs 40/100, Loss=0.452950
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:24,  5.94s/it]
#
# Overall Acc: 0.695372
# Mean Acc: 0.551619
# FreqW Acc: 0.530034
# Mean IoU: 0.436208
#
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/best_0_2.pth
# Epoch 1, Itrs 50/100, Loss=0.349596
# Epoch 1, Itrs 60/100, Loss=0.306550
# Model saved as checkpoints/last_conv_unfreeze_1_overfit/latest_0_2.pth
# validation...
# 95it [09:22,  5.92s/it]
#
# ...

# %%
"""Experiment 1: train ASPP main classifier with coarse search over lr, focal gamma"""
# Results from training to 60 epochs on (lr, gamma) pairs
# Searched lr in [5e-4, 5e-3], gamma in [1, 3]

# BEST to WORST
# (1e-3, 2) --> loss dropped to 0.3 (closer to 0.2)
# (7.35e-4, 1.57) --> loss dropped to 0.3 at very end (above it most time)
# (6.76e-4, 1.03) --> loss dropped to 0.4
# (1e-2, 2) -- loss exploded (from 2 to 20)
# (3.59e-3, 2.30) -- loss exploded (from 2 to 20)

list(zip(np.random.uniform(1, 9, size=3), np.random.uniform(1, 3, size=3)))
# Out:
# [(7.356510594245754, 1.57122872489919),
#  (3.5931236577930603, 2.3090547323867785),
#  (6.761548248011835, 1.0353207283508874)]

# %%
# (6.76e-4, 1.03)
# !python main.py \
    --unfreeze_to 'ASPP' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 6.76e-4 \
    --focal_gamma 1.03 \
    --total_itrs 100 \
    --loss_type focal_loss \
    --exp_name 1_change_dropout \
    --goal_name aspp_unfreeze \
    --batch_size 6 \
    --val_batch_size 4 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Unfreezing down to ASPP
#      layer6.conv2d_list.0.0
#      layer6.conv2d_list.0.1
#      layer6.conv2d_list.1.0
#      layer6.conv2d_list.1.1
#      layer6.conv2d_list.2.0
#      layer6.conv2d_list.2.1
#      layer6.conv2d_list.3.0
#      layer6.conv2d_list.3.1
#      layer6.conv2d_list.4.0
#      layer6.conv2d_list.4.1
#      layer6.bottleneck.0.se.0
#      layer6.bottleneck.0.se.2
#      layer6.bottleneck.1
#      layer6.bottleneck.2
#      layer6.head.1
# Numbers of parameters:  35210832
# Epoch 1, Itrs 10/100, Loss=0.646499
# Epoch 1, Itrs 20/100, Loss=0.562446
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/latest_0_6.pth
# validation...
# 48it [10:16, 12.83s/it]
#
# Overall Acc: 0.643966
# Mean Acc: 0.513048
# FreqW Acc: 0.455698
# Mean IoU: 0.369229
#
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/best_0_6.pth
# Epoch 1, Itrs 30/100, Loss=0.554796
# ...

# %%
# (7.35e-4, 1.57)
# !python main.py \
    --unfreeze_to 'ASPP' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --learning_rate 7.35e-4 \
    --focal_gamma 1.57 \
    --total_itrs 100 \
    --loss_type focal_loss \
    --exp_name 1_change_dropout \
    --goal_name aspp_unfreeze \
    --batch_size 6 \
    --val_batch_size 4 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Unfreezing down to ASPP
#      layer6.conv2d_list.0.0
#      layer6.conv2d_list.0.1
#      layer6.conv2d_list.1.0
#      layer6.conv2d_list.1.1
#      layer6.conv2d_list.2.0
#      layer6.conv2d_list.2.1
#      layer6.conv2d_list.3.0
#      layer6.conv2d_list.3.1
#      layer6.conv2d_list.4.0
#      layer6.conv2d_list.4.1
#      layer6.bottleneck.0.se.0
#      layer6.bottleneck.0.se.2
#      layer6.bottleneck.1
#      layer6.bottleneck.2
#      layer6.head.1
# Numbers of parameters:  35210832
# Epoch 1, Itrs 10/100, Loss=0.591947
# Epoch 1, Itrs 20/100, Loss=0.462191
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/latest_0_6.pth
# validation...
# 48it [10:15, 12.83s/it]
#
# Overall Acc: 0.619428
# Mean Acc: 0.496658
# FreqW Acc: 0.424940
# Mean IoU: 0.347383
#
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/best_0_6.pth
# Epoch 1, Itrs 30/100, Loss=0.459892
# ...

# %%
# (1e-3, 2)
# !python main.py \
    --unfreeze_to 'ASPP' \
    --restore-from checkpoints/converging_head_1_change_lr/latest_0_8.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --total_itrs 100 \
    --loss_type focal_loss \
    --learning_rate 1e-3 \
    --exp_name 1_change_dropout \
    --goal_name aspp_unfreeze \
    --batch_size 6 \
    --val_batch_size 4 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 20 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Unfreezing down to ASPP
#      layer6.conv2d_list.0.0
#      layer6.conv2d_list.0.1
#      layer6.conv2d_list.1.0
#      layer6.conv2d_list.1.1
#      layer6.conv2d_list.2.0
#      layer6.conv2d_list.2.1
#      layer6.conv2d_list.3.0
#      layer6.conv2d_list.3.1
#      layer6.conv2d_list.4.0
#      layer6.conv2d_list.4.1
#      layer6.bottleneck.0.se.0
#      layer6.bottleneck.0.se.2
#      layer6.bottleneck.1
#      layer6.bottleneck.2
#      layer6.head.1
# Numbers of parameters:  35210832
# Epoch 1, Itrs 10/100, Loss=0.719327
# Epoch 1, Itrs 20/100, Loss=0.411039
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/latest_0_6.pth
# validation...
# 48it [10:15, 12.82s/it]
#
# Overall Acc: 0.609598
# Mean Acc: 0.490642
# FreqW Acc: 0.414429
# Mean IoU: 0.342127
#
# Model saved as checkpoints/aspp_unfreeze_1_change_dropout/best_0_6.pth
# Epoch 1, Itrs 30/100, Loss=0.360231
# ...

# %%
"""Experiment 0: train new head to convergence"""

# %%
# lr = 1.3e-2
# Results: convergence after 60 epochs
# !python main.py \
    --unfreeze_to 'head' \
    --restore-from ./pretrained_weights/SE_GN_batchsize2_1024x512_pp_ms_me0_classbalance7_kl0.1_lr2_drop0.1_seg0.5/GTA5_25000_new_head.pth \
    --droprate 0 \
    --use-se \
    --norm-style gn \
    --total_itrs 100 \
    --loss_type focal_loss \
    --learning_rate 1.3e-2 \
    --exp_name 1_change_lr \
    --goal_name converging_head \
    --batch_size 8 \
    --val_batch_size 4 \
    --output_stride 16 \
    --ckpt ./checkpoints/pretrained_resnet101_v3plus_uninit_head.pth \
    --val_interval 30 \
    --no_aug \
    --enable_vis \
    --vis_port 7000 \
    --vis_num_samples 3 \
    --dataset potsdam \
    --data_root ./data/ \
    --num_classes 6 \
    --gpu_id 0
# Out:
# Setting up a new session...
# Device: cuda
# Dataset: potsdam, Train set: 646, Val set: 190
# Unfreezing down to head
#      layer5.head.1
#      layer6.head.1
# Numbers of parameters:  6144
# Epoch 1, Itrs 10/100, Loss=1.013586
# Epoch 1, Itrs 20/100, Loss=1.041384
# Epoch 1, Itrs 30/100, Loss=0.923195
# Model saved as checkpoints/converging_head_1_change_lr/latest_0_8.pth
# validation...
# 48it [10:13, 12.79s/it]
#
# Overall Acc: 0.303762
# Mean Acc: 0.166598
# FreqW Acc: 0.095065
# Mean IoU: 0.052380
#
# Model saved as checkpoints/converging_head_1_change_lr/latest_0_8.pth
# Epoch 1, Itrs 40/100, Loss=1.008158
# Epoch 1, Itrs 50/100, Loss=0.871555
# Epoch 1, Itrs 60/100, Loss=0.694220
# Model saved as checkpoints/converging_head_1_change_lr/latest_0_8.pth
# validation...
# 48it [10:15, 12.83s/it]
#
# Overall Acc: 0.424555
# Mean Acc: 0.273765
# FreqW Acc: 0.233273
# Mean IoU: 0.160482
#
# Model saved as checkpoints/converging_head_1_change_lr/latest_0_8.pth
# ...
