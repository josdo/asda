# %%
import pathlib
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
# !python evaluate_dstl.py --restore-from ./snapshots/exp2/dstl_3000.pth
# Out:
# evaluate_dstl.py:122: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)
# ModelType:DeepLab
# NormType:gn
# >>>>Extracting feature...000/264multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/PIL/Image.py", line 2138, in save
#     format = EXTENSION[ext]
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/conda/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "evaluate_dstl.py", line 94, in save
#     output.save('%s' % (name))
# ...

# %%
import sys
sys.path.append('./')

img_dir = './result/dstl/exp2/'
paths = ['./' + p.as_posix() for p in pathlib.Path(img_dir).glob('*.png')]
print(paths)
# Out:
# ['./result/dstl/exp2/6060_2_3_201_1174.png_color.png', './result/dstl/exp2/6110_4_0_2198_174.png', './result/dstl/exp2/6060_2_3_1201_174.png_color.png', './result/dstl/exp2/6140_1_2_198_2174.png_scoremap.png', './result/dstl/exp2/6100_1_3_2195_174.png_heatmap.png', './result/dstl/exp2/6120_2_2_201_1174.png_heatmap.png', './result/dstl/exp2/6100_2_2_195_1174.png_heatmap.png', './result/dstl/exp2/6140_1_2_2198_174.png_color.png', './result/dstl/exp2/6110_3_1_198_174.png', './result/dstl/exp2/6120_2_0_2201_174.png_heatmap.png', './result/dstl/exp2/6100_2_2_1195_174.png_heatmap.png', './result/dstl/exp2/6110_3_1_1198_1174.png', './result/dstl/exp2/6110_1_2_2198_174.png_scoremap.png', './result/dstl/exp2/6100_1_3_1195_174.png_scoremap.png', './result/dstl/exp2/6110_4_0_198_2174.png_scoremap.png', './result/dstl/exp2/6070_2_3_1169_175.png', './result/dstl/exp2/6140_1_2_2198_174.png_heatmap.png', './result/dstl/exp2/6100_1_3_2195_2174.png_scoremap.png', './result/dstl/exp2/6060_2_3_2201_117
# ...

# %%
print(paths[0])
# Out:
# ./result/dstl/baseline_run/6110_4_0_2198_174.png

# %%
from dataset.dstl_dataset import Dstl

arr = np.asarray(Image.open('./result/dstl/exp2/6110_3_1_2198_2174.png'))
print(arr)
label = Dstl.decode_target(arr)
plt.imshow(label)
# Out:
# [[2 2 2 ... 2 2 2]
#  [2 2 2 ... 2 2 2]
#  [2 2 2 ... 2 2 2]
#  ...
#  [2 2 2 ... 2 2 2]
#  [2 2 2 ... 2 2 2]
#  [2 2 2 ... 2 2 2]]

# %%
gt_arr = np.load('./data/dstl/masks/6110_3_1_2198_2174.npy')
gt_label = Dstl.decode_target(gt_arr)
plt.imshow(gt_label)

# %%
Image.open('./data/dstl/imgs/6110_3_1_2198_2174.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x1000 at 0x7FF5163F6D90>

# %%
Image.open('./result/dstl/exp2/6140_1_2_2198_1174.png_heatmap.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480 at 0x7FF5163FE150>
